# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("preprocessed_final.csv")
data = train.iloc[:,1:].to_numpy() / 255.0

# %%
plt.figure(figsize=(12, 10))
for i in range(20):
    plt.subplot(5, 4, i+1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(data[i+1000].reshape(28,28))
